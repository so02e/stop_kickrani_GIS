# %% [markdown]
# ## 기타는 PM

# %%
import pandas as pd

data = pd.read_csv('data/교통 데이터/서울시 통근,통학시 이용 교통수단(2020) 기타는PM.txt', sep = "\t", engine='python')
data
# Out:
#       기간    대분류           분류    도보  자전거 자전거+기타교통수단 오토바이    버스  지하철(철도)  \
# 0   2020    서울시          서울시  18.2  2.5        0.3  0.9  23.3     14.3
# 1   2020     성별           남자  14.0  2.8        0.4  1.3  19.7     14.6
# 2   2020     성별           여자  23.7  2.0        0.3  0.2  28.1     13.8
# 3   2020    연령별          10대  48.3  4.9        0.8    -  34.6      2.0
# 4   2020    연령별          20대  13.6  1.5        0.3  0.7  26.1     18.1
# 5   2020    연령별          30대   9.9  2.9        0.3  0.5  20.6     19.5
# 6   2020    연령별          40대  12.7  2.5        0.4  0.5  18.3     17.0
# 7   2020    연령별          50대  17.3  2.0        0.3    1  20.4     11.8
# 8   2020    연령별       60대 이상  29.5  2.7        0.1  2.2  27.9      7.3
# 9   2020    학력별        중졸 이하  50.7  2.8        0.3  2.6  24.6      4.2
# 10  2020    학력별        고졸 이하  27.7  3.2        0.2  1.5  30.0      8.4
# 11  2020    학력별        대졸 이하  10.8  2.1        0.3  0.4  21.2     17.7
# ...

# %%
data_total = data[data["대분류"] == "서울시"]
data_total
# Out:
#      기간  대분류   분류    도보  자전거 자전거+기타교통수단 오토바이    버스  지하철(철도)  버스+지하철   택시  \
# 0  2020  서울시  서울시  18.2  2.5        0.3  0.9  23.3     14.3    21.2  0.1
#
#     승용차  승용차+버스  승용차+지하철   기타
# 0  16.5     0.9      1.5  0.3

# %%
data_total = data_total[['대분류','도보','자전거','자전거+기타교통수단','오토바이','버스','지하철(철도)','버스+지하철','택시','승용차','승용차+버스','승용차+지하철','기타']]
data_total
# Out:
#    대분류    도보  자전거 자전거+기타교통수단 오토바이    버스  지하철(철도)  버스+지하철   택시   승용차  승용차+버스  \
# 0  서울시  18.2  2.5        0.3  0.9  23.3     14.3    21.2  0.1  16.5     0.9
#
#    승용차+지하철   기타
# 0      1.5  0.3

# %%
data_total = data_total.set_index('대분류')

# %%
data_total.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='대분류'>

# %%
data_sex = data[data["대분류"] == "성별"]
data_sex = data_sex[['분류','도보','자전거','자전거+기타교통수단','오토바이','버스','지하철(철도)','버스+지하철','택시','승용차','승용차+버스','승용차+지하철','기타']]
data_sex = data_sex.set_index('분류')
data_sex
# Out:
#       도보  자전거 자전거+기타교통수단 오토바이    버스  지하철(철도)  버스+지하철   택시   승용차  승용차+버스  \
# 분류
# 남자  14.0  2.8        0.4  1.3  19.7     14.6    20.7  0.1  23.1     1.0
# 여자  23.7  2.0        0.3  0.2  28.1     13.8    21.7  0.1   8.0     0.7
#
#     승용차+지하철   기타
# 분류
# 남자      1.9  0.3
# 여자      1.1  0.3

# %%
data_age = data[data["대분류"] == "연령별"]
data_age = data_age[['분류','도보','자전거','자전거+기타교통수단','오토바이','버스','지하철(철도)','버스+지하철','택시','승용차','승용차+버스','승용차+지하철','기타']]
data_age = data_age.set_index('분류')
data_age
# Out:
#           도보  자전거 자전거+기타교통수단 오토바이    버스  지하철(철도)  버스+지하철   택시   승용차  승용차+버스  \
# 분류
# 10대     48.3  4.9        0.8    -  34.6      2.0     8.8    -   0.3     0.0
# 20대     13.6  1.5        0.3  0.7  26.1     18.1    34.2  0.1   3.8     0.5
# 30대      9.9  2.9        0.3  0.5  20.6     19.5    24.9  0.2  17.7     1.0
# 40대     12.7  2.5        0.4  0.5  18.3     17.0    20.1  0.2  23.8     1.6
# 50대     17.3  2.0        0.3    1  20.4     11.8    16.8  0.2  26.8     1.1
# 60대 이상  29.5  2.7        0.1  2.2  27.9      7.3    10.9  0.1  18.2     0.5
#
#         승용차+지하철   기타
# 분류
# 10대         0.2    -
# 20대         0.7  0.4
# 30대         2.1  0.3
# 40대         2.3  0.5
# 50대         2.2  0.2
# 60대 이상      0.6  0.1

# %%
# 27부터, 51행 

data_gu = data.loc[27:51]
data_gu = data_gu[['분류','도보','자전거','자전거+기타교통수단','오토바이','버스','지하철(철도)','버스+지하철','택시','승용차','승용차+버스','승용차+지하철','기타']]
data_gu = data_gu.set_index('분류')
data_gu
# Out:
#         도보  자전거 자전거+기타교통수단 오토바이    버스  지하철(철도)  버스+지하철   택시   승용차  승용차+버스  \
# 분류
# 종로구   21.3  3.1        0.2  1.4  27.9      9.7    17.9  0.2  16.3     1.6
# 중구    23.4  1.7        0.5  0.9  22.5     14.9    21.6    -  11.1     0.4
# 용산구   27.2  2.1        0.5    2  24.3      8.7    15.3    0  17.7     0.7
# 성동구   19.7  2.6        1.3  0.2  17.0     18.2    22.5    0  15.8     0.5
# 광진구   24.0  2.9          -  0.5  21.6     18.0    19.6  0.1  11.0     0.9
# 동대문구  15.7  2.3        0.5  1.7  24.6     14.3    19.7  0.1  18.9     1.2
# 중랑구   14.2  2.8        0.6  0.5  26.6     15.3    19.2    -  18.3     0.8
# 성북구   16.4  2.6        0.2  2.1  24.1     13.6    23.7  0.4  14.2     0.9
# 강북구   17.6  2.0        0.1  0.8  24.5     11.6    20.5    0  20.5     0.6
# 도봉구   23.3  3.0        0.1  0.1  23.0     14.2    19.0    -  14.0     0.7
# 노원구   15.4  3.1        0.4  0.3  29.9     12.8    20.0    -  15.2     0.5
# 은평구   13.4  2.2        0.3    0  30.6     13.4    27.0  0.3  10.4     0.5
# ...
