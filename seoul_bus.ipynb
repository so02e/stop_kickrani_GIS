# %% [markdown]
# # 자치구별 정류소번호 앞 2자리 (01~25)
#
# ## 01 종로구
#
# ## 02 중구
#
# ## 03 용산구
#
# ## 04 성동구
#
# ## 05 광진구
#
# ## 06 동대문구
#
# ## 07 중랑구
#
# ## 08 성북구
#
# ## 09 강북구
#
# ## 10 도봉구
#
# ## 11 노원구
#
# ## 12 은평구
#
# ## 13 서대문구
#
# ## 14 마포구
#
# ## 15 양천구
#
# ## 16 강서구
#
# ## 17 구로구
#
# ## 18 금천구
#
# ## 19 영등포구
#
# ## 20 동작구
#
# ## 21 관악구
#
# ## 22 서초구
#
# ## 23 강남구
#
# ## 24 송파구
#
# ## 25 강동구

# %%
import pandas as pd

df1 = pd.read_excel('data/교통 데이터/강남구서초구버스정류장.xlsx')
df1
# Out:
#            표준ID  ARS-ID             정류소명         X좌표        Y좌표
# 0     121000001   22001          교육개발원입구  127.038342  37.478514
# 1     121000002   22002          교육개발원입구  127.038676  37.477767
# 2     121000003   22003     양재역.서초문화예술회관  127.035847  37.482522
# 3     121000004   22004     양재역.서초문화예술회관  127.036825  37.481871
# 4     121000005   22005            뱅뱅사거리  127.032367  37.487592
# ...         ...     ...              ...         ...        ...
# 1161  122900097   23972      수서교회.수서동성당앞  127.094743  37.483491
# 1162  122000286   23981        삼성서울병원사거리  127.082862  37.488968
# 1163  122900073   23993     강남신동아파밀리에2단지  127.101538  37.464601
# 1164  122000287   23994   일원주유소.삼성서울병원후문  127.087681  37.490657
# 1165  122900074   23995  리엔파크4단지.강남데시앙파크  127.101900  37.461227
#
# [1166 rows x 5 columns]

# %%
df1["ARS-ID"].unique()
# Out:
# array([22001, 22002, 22003, ..., 23993, 23994, 23995], dtype=int64)

# %%
df1.describe()
# Out:
#                표준ID        ARS-ID          X좌표          Y좌표
# count  1.166000e+03   1166.000000  1166.000000  1166.000000
# mean   1.217670e+08  22906.771870   127.037236    37.489812
# std    5.456143e+05    553.129535     0.031638     0.019543
# min    1.200007e+08  22001.000000   126.980330    37.430780
# 25%    1.210010e+08  22387.500000   127.014053    37.478648
# 50%    1.219003e+08  22933.500000   127.035452    37.489109
# 75%    1.220002e+08  23345.750000   127.056702    37.501328
# max    1.229001e+08  23995.000000   127.121137    37.781594

# %%
df1.dtypes
# Out:
# 표준ID        int64
# ARS-ID      int64
# 정류소명       object
# X좌표       float64
# Y좌표       float64
# dtype: object

# %%
df2 = pd.read_excel('data/교통 데이터/2020년_강남구서초구버스노선별_정류장별_시간대별_승하차_인원_정보.xlsx')
df2
# Out:
#          사용년월  노선번호              노선명  표준버스정류장ID  버스정류장ARS번호              역명  \
# 0      202001   140  140번(도봉산역~AT센터)  121000001       22001         교육개발원입구
# 1      202001   140  140번(도봉산역~AT센터)  121000002       22002         교육개발원입구
# 2      202001   140  140번(도봉산역~AT센터)  121000003       22003    양재역.서초문화예술회관
# 3      202001   140  140번(도봉산역~AT센터)  121000004       22004    양재역.서초문화예술회관
# 4      202001   140  140번(도봉산역~AT센터)  121000005       22005           뱅뱅사거리
# ...       ...   ...              ...        ...         ...             ...
# 47101  202012  8541   8541번(호압사~강남역)  121000530       22033            정금마을
# 47102  202012  8541   8541번(호압사~강남역)  121000531       22031          경문고등학교
# 47103  202012  8541   8541번(호압사~강남역)  121000532       22029  총신대입구역.남성시장입구앞
# 47104  202012  8541   8541번(호압사~강남역)  121000533       22027             이수역
# 47105  202012  8541   8541번(호압사~강남역)  122000182       23285             강남역
#
# ...

# %%
df2["버스정류장ARS번호"].unique()
# Out:
# array([22001, 22002, 22003, ..., 22200, 23822, 23617], dtype=int64)

# %%
df2["버스정류장ARS번호"].unique()
# Out:
# array([ 1002,  1003,  1005, ...,  4899,  4896, 13977], dtype=int64)

# %%
df2.describe()
# Out:
#                 사용년월     표준버스정류장ID    버스정류장ARS번호     00시승차총승객수     00시하차총승객수  \
# count   47106.000000  4.710600e+04  47106.000000  47106.000000  47106.000000
# mean   202006.492612  1.218964e+08  22846.349573     28.692990     24.676708
# std         3.453563  4.805845e+06    561.848613     87.523974     59.894269
# min    202001.000000  1.020003e+08  22001.000000      0.000000      0.000000
# 25%    202003.000000  1.210002e+08  22270.000000      0.000000      0.000000
# 50%    202006.000000  1.220000e+08  23122.000000      0.000000      0.000000
# 75%    202009.000000  1.220002e+08  23315.000000     18.000000     22.000000
# max    202012.000000  2.220006e+08  23998.000000   1935.000000   1049.000000
#
#            1시승차총승객수      1시하차총승객수      2시승차총승객수      2시하차총승객수      3시승차총승객수  \
# count  47106.000000  47106.000000  47106.000000  47106.000000  47106.000000
# mean       6.229652      5.515752      3.150214      2.482083      2.676899
# ...

# %%
df2 = df2[df2["버스정류장ARS번호"] <= 26000]

# %%
df2
# Out:
#           사용년월  노선번호              노선명  표준버스정류장ID  버스정류장ARS번호               역명  \
# 0       202001   100   100번(하계동~용산구청)  100000002        1002      창경궁.서울대학교병원
# 1       202001   100   100번(하계동~용산구청)  100000003        1003        명륜3가.성대입구
# 2       202001   100   100번(하계동~용산구청)  100000005        1005    혜화동로터리.여운형활동터
# 3       202001   100   100번(하계동~용산구청)  100000102        1198              원남동
# 4       202001   100   100번(하계동~용산구청)  100000108        1204  종로5가.효제동.김상옥의거터
# ...        ...   ...              ...        ...         ...              ...
# 468780  202012  9714  9714번(교하운정~서울역)  111000008       12008        디지털미디어시티역
# 468781  202012  9714  9714번(교하운정~서울역)  112000005       13005        모래내시장.가좌역
# 468782  202012  9714  9714번(교하운정~서울역)  112000006       13006        모래내시장.가좌역
# 468783  202012  9714  9714번(교하운정~서울역)  112000012       13012             연세대앞
# 468784  202012  9714  9714번(교하운정~서울역)  112000013       13013             연세대앞
#
# ...

# %%
df2.dtypes
# Out:
# 사용년월           int64
# 노선번호          object
# 노선명           object
# 표준버스정류장ID     object
# 버스정류장ARS번호     int64
# 역명            object
# 00시승차총승객수      int64
# 00시하차총승객수      int64
# 1시승차총승객수       int64
# 1시하차총승객수       int64
# 2시승차총승객수       int64
# 2시하차총승객수       int64
# 3시승차총승객수       int64
# 3시하차총승객수       int64
# 4시승차총승객수       int64
# 4시하차총승객수       int64
# 5시승차총승객수       int64
# 5시하차총승객수       int64
# 6시승차총승객수       int64
# 6시하차총승객수       int64
# 7시승차총승객수       int64
# 7시하차총승객수       int64
# 8시승차총승객수       int64
# 8시하차총승객수       int64
# 9시승차총승객수       int64
# 9시하차총승객수       int64
# 10시승차총승객수      int64
# 10시하차총승객수      int64
# 11시승차총승객수      int64
# 11시하차총승객수      int64
# 12시승차총승객수      int64
# 12시하차총승객수      int64
# 13시승차총승객수      int64
# 13시하차총승객수      int64
# 14시승차총승객수      int64
# 14시하차총승객수      int64
# 15시승차총승객수      int64
# 15시하차총승객수      int64
# 16시승차총승객수      int64
# 16시하차총승객수      int64
# 17시승차총승객수      int64
# 17시하차총승객수      int64
# 18시승차총승객수      int64
# ...

# %%
df2.sort_values(by='버스정류장ARS번호',ascending = False)
# Out:
#          사용년월  노선번호                    노선명  표준버스정류장ID  버스정류장ARS번호  \
# 6130   202002  강남06  강남06(세곡LH푸르지오아파트~코엑스)  122900072       23998
# 21827  202006  강남06  강남06(세곡LH푸르지오아파트~코엑스)  122900072       23998
# 10050  202003  강남06  강남06(세곡LH푸르지오아파트~코엑스)  122900072       23998
# 2197   202001  강남06  강남06(세곡LH푸르지오아파트~코엑스)  122900072       23998
# 13974  202004  강남06  강남06(세곡LH푸르지오아파트~코엑스)  122900072       23998
# ...       ...   ...                    ...        ...         ...
# 15335  202004   440     440번(송파공영차고지~압구정동)  121000001       22001
# 11636  202003  9404        9404번(분당구미~신사역)  121000001       22001
# 34778  202009   470       470번(상암차고지~안골마을)  121000001       22001
# 11589  202003  9408       9408번(성남 분당~영등포)  121000001       22001
# 0      202001   140        140번(도봉산역~AT센터)  121000001       22001
#
#                   역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 6130   은곡마을입구.세곡리엔파크          0         43         0         0  ...
# ...

# %%
df2
# Out:
#           사용년월  노선번호              노선명  표준버스정류장ID  버스정류장ARS번호               역명  \
# 0       202001   100   100번(하계동~용산구청)  100000002        1002      창경궁.서울대학교병원
# 1       202001   100   100번(하계동~용산구청)  100000003        1003        명륜3가.성대입구
# 2       202001   100   100번(하계동~용산구청)  100000005        1005    혜화동로터리.여운형활동터
# 3       202001   100   100번(하계동~용산구청)  100000102        1198              원남동
# 4       202001   100   100번(하계동~용산구청)  100000108        1204  종로5가.효제동.김상옥의거터
# ...        ...   ...              ...        ...         ...              ...
# 468780  202012  9714  9714번(교하운정~서울역)  111000008       12008        디지털미디어시티역
# 468781  202012  9714  9714번(교하운정~서울역)  112000005       13005        모래내시장.가좌역
# 468782  202012  9714  9714번(교하운정~서울역)  112000006       13006        모래내시장.가좌역
# 468783  202012  9714  9714번(교하운정~서울역)  112000012       13012             연세대앞
# 468784  202012  9714  9714번(교하운정~서울역)  112000013       13013             연세대앞
#
# ...

# %%
df2["버스정류장ARS번호"]
# Out:
# 0        22001
# 1        22002
# 2        22003
# 3        22004
# 4        22005
#          ...
# 47101    22033
# 47102    22031
# 47103    22029
# 47104    22027
# 47105    23285
# Name: 버스정류장ARS번호, Length: 47106, dtype: int64

# %%
df2
# Out:
#          사용년월  노선번호              노선명  표준버스정류장ID  버스정류장ARS번호              역명  \
# 0      202001   140  140번(도봉산역~AT센터)  121000001       22001         교육개발원입구
# 1      202001   140  140번(도봉산역~AT센터)  121000002       22002         교육개발원입구
# 2      202001   140  140번(도봉산역~AT센터)  121000003       22003    양재역.서초문화예술회관
# 3      202001   140  140번(도봉산역~AT센터)  121000004       22004    양재역.서초문화예술회관
# 4      202001   140  140번(도봉산역~AT센터)  121000005       22005           뱅뱅사거리
# ...       ...   ...              ...        ...         ...             ...
# 47101  202012  8541   8541번(호압사~강남역)  121000530       22033            정금마을
# 47102  202012  8541   8541번(호압사~강남역)  121000531       22031          경문고등학교
# 47103  202012  8541   8541번(호압사~강남역)  121000532       22029  총신대입구역.남성시장입구앞
# 47104  202012  8541   8541번(호압사~강남역)  121000533       22027             이수역
# 47105  202012  8541   8541번(호압사~강남역)  122000182       23285             강남역
#
# ...

# %%
grouped = df2.groupby(df2['버스정류장ARS번호']).mean()
grouped
# Out:
#                      사용년월    표준버스정류장ID   00시승차총승객수  00시하차총승객수   1시승차총승객수  \
# 버스정류장ARS번호
# 22001       202006.462185  121000001.0   20.882353  35.605042   4.764706
# 22002       202006.500000  121000002.0   20.181818  11.984848   0.765152
# 22003       202006.500000  121000003.0  138.673611  54.152778  28.347222
# 22004       202006.500000  121000004.0   36.602564  18.500000   1.108974
# 22005       202006.477833  121000005.0   46.674877  37.192118  12.871921
# ...                   ...          ...         ...        ...        ...
# 23983       202005.900000  122000712.0    0.000000   0.200000   0.100000
# 23993       202006.500000  122900073.0    0.000000   0.000000   0.000000
# 23994       202007.064516  122000287.0    4.161290   1.193548   0.000000
# 23995       202006.500000  122900074.0    0.000000   0.000000   0.000000
# 23998       202003.500000  122900072.0    1.833333  32.666667   0.000000
#
#              1시하차총승객수  2시승차총승객수  2시하차총승객수  3시승차총승객수  3시하차총승객수  ...  \
# ...

# %%
grouped.columns
# Out:
# Index(['사용년월', '표준버스정류장ID', '00시승차총승객수', '00시하차총승객수', '1시승차총승객수', '1시하차총승객수',
#        '2시승차총승객수', '2시하차총승객수', '3시승차총승객수', '3시하차총승객수', '4시승차총승객수', '4시하차총승객수',
#        '5시승차총승객수', '5시하차총승객수', '6시승차총승객수', '6시하차총승객수', '7시승차총승객수', '7시하차총승객수',
#        '8시승차총승객수', '8시하차총승객수', '9시승차총승객수', '9시하차총승객수', '10시승차총승객수',
#        '10시하차총승객수', '11시승차총승객수', '11시하차총승객수', '12시승차총승객수', '12시하차총승객수',
#        '13시승차총승객수', '13시하차총승객수', '14시승차총승객수', '14시하차총승객수', '15시승차총승객수',
#        '15시하차총승객수', '16시승차총승객수', '16시하차총승객수', '17시승차총승객수', '17시하차총승객수',
#        '18시승차총승객수', '18시하차총승객수', '19시승차총승객수', '19시하차총승객수', '20시승차총승객수',
#        '20시하차총승객수', '21시승차총승객수', '21시하차총승객수', '22시승차총승객수', '22시하차총승객수',
#        '23시승차총승객수', '23시하차총승객수', '등록일자'],
#       dtype='object')

# %%
grouped = grouped[['00시승차총승객수', '00시하차총승객수', '1시승차총승객수', '1시하차총승객수',
       '2시승차총승객수', '2시하차총승객수', '3시승차총승객수', '3시하차총승객수', '4시승차총승객수', '4시하차총승객수',
       '5시승차총승객수', '5시하차총승객수', '6시승차총승객수', '6시하차총승객수', '7시승차총승객수', '7시하차총승객수',
       '8시승차총승객수', '8시하차총승객수', '9시승차총승객수', '9시하차총승객수', '10시승차총승객수',
       '10시하차총승객수', '11시승차총승객수', '11시하차총승객수', '12시승차총승객수', '12시하차총승객수',
       '13시승차총승객수', '13시하차총승객수', '14시승차총승객수', '14시하차총승객수', '15시승차총승객수',
       '15시하차총승객수', '16시승차총승객수', '16시하차총승객수', '17시승차총승객수', '17시하차총승객수',
       '18시승차총승객수', '18시하차총승객수', '19시승차총승객수', '19시하차총승객수', '20시승차총승객수',
       '20시하차총승객수', '21시승차총승객수', '21시하차총승객수', '22시승차총승객수', '22시하차총승객수',
       '23시승차총승객수', '23시하차총승객수']]

grouped
# Out:
#              00시승차총승객수  00시하차총승객수   1시승차총승객수   1시하차총승객수  2시승차총승객수  2시하차총승객수  \
# 버스정류장ARS번호
# 22001        20.882353  35.605042   4.764706  11.436975  0.008403  0.016807
# 22002        20.181818  11.984848   0.765152   0.022727  0.000000  0.000000
# 22003       138.673611  54.152778  28.347222  17.708333  0.027778  0.006944
# 22004        36.602564  18.500000   1.108974   0.076923  0.000000  0.000000
# 22005        46.674877  37.192118  12.871921  14.408867  0.812808  3.261084
# ...                ...        ...        ...        ...       ...       ...
# 23983         0.000000   0.200000   0.100000   0.200000  0.000000  0.000000
# 23993         0.000000   0.000000   0.000000   0.000000  0.000000  0.000000
# 23994         4.161290   1.193548   0.000000   0.000000  0.000000  0.000000
# 23995         0.000000   0.000000   0.000000   0.000000  0.000000  0.000000
# 23998         1.833333  32.666667   0.000000   0.000000  0.000000  0.000000
#
# ...

# %% [markdown]
# ## 아침 하차

# %%
아침하차 = grouped[['7시하차총승객수','8시하차총승객수','9시하차총승객수','10시하차총승객수']]

# %% [markdown]
# ## 저녁 승차

# %%
저녁승차 = grouped[['17시승차총승객수','18시승차총승객수','19시승차총승객수','20시승차총승객수']]

# %% [markdown]
# ## 아침승차

# %%
아침승차 = grouped[['6시승차총승객수','7시승차총승객수','8시승차총승객수','9시승차총승객수']]

# %% [markdown]
# ## 저녁하차

# %%
저녁하차 = grouped[['18시하차총승객수','19시하차총승객수','20시하차총승객수','21시하차총승객수']]

# %%
ndf1 = df1.set_index(['ARS-ID'])
ndf1
# Out:
#              표준ID             정류소명         X좌표        Y좌표
# ARS-ID
# 22001   121000001          교육개발원입구  127.038342  37.478514
# 22002   121000002          교육개발원입구  127.038676  37.477767
# 22003   121000003     양재역.서초문화예술회관  127.035847  37.482522
# 22004   121000004     양재역.서초문화예술회관  127.036825  37.481871
# 22005   121000005            뱅뱅사거리  127.032367  37.487592
# ...           ...              ...         ...        ...
# 23972   122900097      수서교회.수서동성당앞  127.094743  37.483491
# 23981   122000286        삼성서울병원사거리  127.082862  37.488968
# 23993   122900073     강남신동아파밀리에2단지  127.101538  37.464601
# 23994   122000287   일원주유소.삼성서울병원후문  127.087681  37.490657
# 23995   122900074  리엔파크4단지.강남데시앙파크  127.101900  37.461227
#
# [1166 rows x 4 columns]

# %%
아침하차merge = ndf1.join(아침하차, how='left')
아침하차merge
# Out:
#              표준ID             정류소명         X좌표        Y좌표    7시하차총승객수  \
# ARS-ID
# 22001   121000001          교육개발원입구  127.038342  37.478514  143.907563
# 22002   121000002          교육개발원입구  127.038676  37.477767  183.606061
# 22003   121000003     양재역.서초문화예술회관  127.035847  37.482522  166.201389
# 22004   121000004     양재역.서초문화예술회관  127.036825  37.481871  264.807692
# 22005   121000005            뱅뱅사거리  127.032367  37.487592  168.369458
# ...           ...              ...         ...        ...         ...
# 23972   122900097      수서교회.수서동성당앞  127.094743  37.483491   87.333333
# 23981   122000286        삼성서울병원사거리  127.082862  37.488968  226.000000
# 23993   122900073     강남신동아파밀리에2단지  127.101538  37.464601   29.958333
# 23994   122000287   일원주유소.삼성서울병원후문  127.087681  37.490657  530.580645
# 23995   122900074  리엔파크4단지.강남데시앙파크  127.101900  37.461227   34.395833
#
#           8시하차총승객수    9시하차총승객수   10시하차총승객수
# ARS-ID
# 22001   422.840336  237.655462   90.336134
# ...

# %%
아침하차merge.to_csv("output/강남구서초구정류장아침하차.csv")

# %%
아침승차merge = ndf1.join(아침승차, how='left')
아침승차merge
# Out:
#              표준ID             정류소명         X좌표        Y좌표    6시승차총승객수  \
# ARS-ID
# 22001   121000001          교육개발원입구  127.038342  37.478514   46.605042
# 22002   121000002          교육개발원입구  127.038676  37.477767   63.765152
# 22003   121000003     양재역.서초문화예술회관  127.035847  37.482522  195.208333
# 22004   121000004     양재역.서초문화예술회관  127.036825  37.481871   53.070513
# 22005   121000005            뱅뱅사거리  127.032367  37.487592   94.743842
# ...           ...              ...         ...        ...         ...
# 23972   122900097      수서교회.수서동성당앞  127.094743  37.483491   22.833333
# 23981   122000286        삼성서울병원사거리  127.082862  37.488968   16.416667
# 23993   122900073     강남신동아파밀리에2단지  127.101538  37.464601   11.625000
# 23994   122000287   일원주유소.삼성서울병원후문  127.087681  37.490657  237.806452
# 23995   122900074  리엔파크4단지.강남데시앙파크  127.101900  37.461227  242.062500
#
#           7시승차총승객수    8시승차총승객수    9시승차총승객수
# ARS-ID
# 22001    75.453782  109.529412   55.630252
# ...

# %%
아침승차merge.to_csv("output/강남구서초구정류장아침승차.csv")

# %%
저녁하차merge = ndf1.join(저녁하차, how='left')
저녁하차merge
# Out:
#              표준ID             정류소명         X좌표        Y좌표    18시하차총승객수  \
# ARS-ID
# 22001   121000001          교육개발원입구  127.038342  37.478514   155.462185
# 22002   121000002          교육개발원입구  127.038676  37.477767   358.469697
# 22003   121000003     양재역.서초문화예술회관  127.035847  37.482522   229.638889
# 22004   121000004     양재역.서초문화예술회관  127.036825  37.481871  1097.993590
# 22005   121000005            뱅뱅사거리  127.032367  37.487592   245.325123
# ...           ...              ...         ...        ...          ...
# 23972   122900097      수서교회.수서동성당앞  127.094743  37.483491    32.166667
# 23981   122000286        삼성서울병원사거리  127.082862  37.488968   229.083333
# 23993   122900073     강남신동아파밀리에2단지  127.101538  37.464601   210.500000
# 23994   122000287   일원주유소.삼성서울병원후문  127.087681  37.490657   483.064516
# 23995   122900074  리엔파크4단지.강남데시앙파크  127.101900  37.461227   219.208333
#
#          19시하차총승객수   20시하차총승객수   21시하차총승객수
# ARS-ID
# 22001   140.571429   99.974790   98.445378
# ...

# %%
저녁하차merge.to_csv("output/강남구서초구정류장저녁하차.csv")

# %%
저녁승차merge = ndf1.join(저녁승차, how='left')
저녁승차merge
# Out:
#              표준ID             정류소명         X좌표        Y좌표   17시승차총승객수  \
# ARS-ID
# 22001   121000001          교육개발원입구  127.038342  37.478514  157.025210
# 22002   121000002          교육개발원입구  127.038676  37.477767  409.878788
# 22003   121000003     양재역.서초문화예술회관  127.035847  37.482522  330.729167
# 22004   121000004     양재역.서초문화예술회관  127.036825  37.481871  271.461538
# 22005   121000005            뱅뱅사거리  127.032367  37.487592  163.512315
# ...           ...              ...         ...        ...         ...
# 23972   122900097      수서교회.수서동성당앞  127.094743  37.483491   62.666667
# 23981   122000286        삼성서울병원사거리  127.082862  37.488968  307.250000
# 23993   122900073     강남신동아파밀리에2단지  127.101538  37.464601   16.833333
# 23994   122000287   일원주유소.삼성서울병원후문  127.087681  37.490657  511.419355
# 23995   122900074  리엔파크4단지.강남데시앙파크  127.101900  37.461227  210.250000
#
#          18시승차총승객수   19시승차총승객수   20시승차총승객수
# ARS-ID
# 22001   203.605042  112.638655   95.067227
# ...

# %%
저녁승차merge.to_csv("output/강남구서초구정류장저녁승차.csv")
