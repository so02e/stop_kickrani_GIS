# %%
import pandas as pd

df = pd.read_excel("data/서울시 시설 데이터/지하철노선위경도정보1.xlsx")
df
# Out:
#            역이름  역지역         위도          경도       호선
# 0    4·19민주묘지역  수도권  37.649527  127.013689  우이신설경전철
# 1        가락시장역  수도권  37.493092  127.118258     03호선
# 2        가락시장역  수도권  37.493092  127.118258     08호선
# 3     가산디지털단지역  수도권  37.480389  126.882644     01호선
# 4     가산디지털단지역  수도권  37.480389  126.882644     07호선
# ..         ...  ...        ...         ...      ...
# 386        회기역  수도권  37.589778  127.058039      경의선
# 387        회현역  수도권  37.558760  126.978428     04호선
# 388     효창공원앞역  수도권  37.539294  126.961394      경의선
# 389     효창공원앞역  수도권  37.539294  126.961394     06호선
# 390        흑석역  수도권  37.509165  126.963445     09호선
#
# [391 rows x 5 columns]

# %%
import json
geo_path = 'data/서울시 geojson/seoul.geojson'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=11,
                 )
fmap=folium.Choropleth(geo_data = geo_str,
               data = data2,
               columns = ['자치구', '종사자밀도비(A/B*100)'],
               fill_color = 'YlGnBu',
               key_on='feature.properties.name').add_to(map)
fmap.geojson.zoom_on_click = False
fmap.geojson.add_child(
    folium.features.GeoJsonTooltip(['name'],labels=False)
)
display(map)

# map.save('output/종사자밀도비 지도시각화.html')

# %%
import folium
seoul_map = folium.Map(location=[37.5617072,126.9745681], zoom_start=13)


for name, lat, lng in zip(df.역이름, df.위도, df.경도):
    folium.CircleMarker([lat, lng],
                        radius=3,         # 원의 반지름
                        fill=True,
                        fill_color='blue',    # 원을 채우는 색
                        fill_opacity=0.7, # 투명도    
                        popup=name
    ).add_to(seoul_map)

display(seoul_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import json
import folium
from folium.plugins import HeatMap

geo_data = "data/HangJeongDong_bucheon2.json"

with open(geo_data,encoding="utf-8") as f:
    geo_data = json.loads(f.read())

    
map_obj = folium.Map(location=[37.50554861215234,126.77550612183495], zoom_start=13) #tiles은 TMS URL, attr은 배경지도 정보
lat = list(new_bus['위도'])
lng = list(new_bus['경도'])
heatMap = HeatMap(zip(lat, lng),
                  min_opacity=0.1,
                  radius=30,  #영향 반경 
                  blur=25,     #스무딩 
                  max_zoom=4,
                  color='Red',
                  #gradient={.5: 'Yellow', .75: 'Orange', 1: 'red'}
)


fmap=folium.Choropleth(geo_data = geo_data,
                       color = "black",
                       nan_fill_color='black',
                       fill_opacity=0.1,
                       fill_color = None).add_to(map_obj)

map_obj.add_child(heatMap)
map_obj
#map_obj.save('output/busheatmap2.html')
