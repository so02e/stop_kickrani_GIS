# %% [markdown]
# # 1. 사망교통사고정보

# %%
import pandas as pd

df = pd.read_csv("data/교통사고 데이터/도로교통공단_사망 교통사고 정보_20201123.csv", encoding = 'ansi')
df
# Out:
#        발생년         발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 0     2019  2019-01-01 00  야  화     1     0     0     0       0    부산  ...
# 1     2019  2019-01-01 03  야  화     1     0     0     0       0    경기  ...
# 2     2019  2019-01-01 16  주  화     1     0     0     0       0    경북  ...
# 3     2019  2019-01-01 19  야  화     1     0     0     0       0    대전  ...
# 4     2019  2019-01-01 21  야  화     1     0     0     0       0    경북  ...
# ...    ...            ... .. ..   ...   ...   ...   ...     ...   ...  ...
# 3228  2019  2019-12-31 05  야  화     1     0     0     0       0    서울  ...
# 3229  2019  2019-12-31 08  주  화     1     1     0     1       0    강원  ...
# 3230  2019  2019-12-31 12  주  화     1     1     0     0       1    경북  ...
# 3231  2019  2019-12-31 12  주  화     1     1     0     1       0    울산  ...
# 3232  2019  2019-12-31 16  주  화     1     0     0     0       0    경남  ...
#
# ...

# %%
PMdeath = df[df.가해자_당사자종별  == "개인형이동수단(PM)"]

# %%
PMdeath
# Out:
#        발생년         발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 392   2019  2019-02-16 19  야  토     1     0     0     0       0    전북  ...
# 1069  2019  2019-05-05 21  야  일     1     0     0     0       0    경기  ...
# 1653  2019  2019-07-12 07  주  금     1     0     0     0       0    충북  ...
# 1788  2019  2019-07-30 07  주  화     1     0     0     0       0    대전  ...
# 2104  2019  2019-09-06 22  야  금     1     0     0     0       0    경북  ...
# 2316  2019  2019-09-29 22  야  일     1     0     0     0       0    서울  ...
# 2637  2019  2019-10-31 09  주  목     1     1     0     1       0    경기  ...
# 3029  2019  2019-12-10 15  주  화     1     0     0     0       0    경기  ...
#
#       사고유형      가해자법규위반 도로형태_대분류   도로형태    가해자_당사자종별 피해자_당사자종별 발생위치X_UTMK  \
# 392     기타  안전운전 의무 불이행      단일로  기타단일로  개인형이동수단(PM)        없음   951016.0
# 1069    기타  안전운전 의무 불이행      단일로  기타단일로  개인형이동수단(PM)        없음   941165.0
# ...

# %%
PMdeath.to_csv("output/PMdeath.csv")

# %%
seoul_PMdeath = df[df.발생지시도 == "서울"]

# %%
seoul_PMdeath = seoul_PMdeath[seoul_PMdeath.가해자_당사자종별  == "개인형이동수단(PM)"]

# %%
seoul_PMdeath
# Out:
#        발생년         발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 2316  2019  2019-09-29 22  야  일     1     0     0     0       0    서울  ...
#
#      사고유형      가해자법규위반 도로형태_대분류   도로형태    가해자_당사자종별 피해자_당사자종별 발생위치X_UTMK  \
# 2316   기타  안전운전 의무 불이행      단일로  기타단일로  개인형이동수단(PM)        없음   950462.0
#
#      발생위치Y_UTMK          경도         위도
# 2316  1949674.0  126.939218  37.545068
#
# [1 rows x 23 columns]

# %%
seoul_death = df[df.발생지시도 == "서울"]

# %%
seoul_death
# Out:
#        발생년         발생년월일시 주야 요일  사망자수  부상자수  중상자수  경상자수  부상신고자수 발생지시도  ...  \
# 7     2019  2019-01-02 10  주  수     1     0     0     0       0    서울  ...
# 17    2019  2019-01-03 12  주  목     1     1     0     1       0    서울  ...
# 18    2019  2019-01-03 17  주  목     1     0     0     0       0    서울  ...
# 47    2019  2019-01-08 04  야  화     1     0     0     0       0    서울  ...
# 110   2019  2019-01-14 17  주  월     1     0     0     0       0    서울  ...
# ...    ...            ... .. ..   ...   ...   ...   ...     ...   ...  ...
# 3187  2019  2019-12-26 16  주  목     1     0     0     0       0    서울  ...
# 3215  2019  2019-12-29 23  야  일     1     0     0     0       0    서울  ...
# 3216  2019  2019-12-30 00  야  월     1     0     0     0       0    서울  ...
# 3227  2019  2019-12-31 01  야  화     1     0     0     0       0    서울  ...
# 3228  2019  2019-12-31 05  야  화     1     0     0     0       0    서울  ...
#
# ...

# %%
seoul_death.to_csv("output/seoul_death.csv")

# %% [markdown]
# # 2. 과속방지턱

# %%
df = pd.read_csv("data/교통 데이터/전국과속방지턱표준데이터.csv", encoding = 'ansi')
df
# Out:
#          과속방지턱관리번호   시도명 시군구명         도로명              소재지도로명주소  \
# 0               11  전라남도  광양시         공영로                   NaN
# 1           634008   강원도  강릉시  성덕포남로182번길                   NaN
# 2         42453002   강원도  강릉시   강릉대로443번길                   NaN
# 3         10000033   강원도  강릉시        보래미길                   NaN
# 4         10000032   강원도  강릉시   강릉대로457번길                   NaN
# ...            ...   ...  ...         ...                   ...
# 18661  20180816035    06   동구         수향길        대전광역시 동구 수향길 7
# 18662  20180816036    06   동구     대동천우안5길  대전광역시 동구  대동천우안5길 38
# 18663  20180816037    06   동구     대동천우안5길   대전광역시 동구 대동천우안5길 32
# 18664  20180816038    06   동구         정보길       대전광역시 동구 정보길 73
# 18665  20180816039    06   동구        토천1길      대전광역시 동구 토천1길 20
#
#                     소재지지번주소         설치장소  과속방지턱재료 과속방지턱형태구분  과속방지턱높이  ...  \
# 0          전라남도 광양시 중동 1602        금광아파트        1         1      0.1  ...
# ...

# %%
서울과속방지턱 = df[df["시도명"]=="서울특별시"]

# %%
서울과속방지턱
# Out:
#                   과속방지턱관리번호    시도명 시군구명        도로명                소재지도로명주소  \
# 144                82000284  서울특별시  강동구    양재대로91길    서울특별시 강동구 양재대로91길 77
# 195    2020-3000000-06-0065  서울특별시  종로구  종로51가길 26     서울특별시 종로구 종로51가길 26
# 196    2020-3000000-06-0065  서울특별시  종로구   종로44길 82      서울특별시 종로구 종로44길 82
# 197    2020-3000000-06-0065  서울특별시  종로구   혜화로9길 20      서울특별시 종로구 혜화로9길 20
# 357                82000002  서울특별시  강동구     상암로81길     서울특별시 강동구 상암로 427-8
# ...                     ...    ...  ...        ...                     ...
# 15263              82000219  서울특별시  강동구  천호대로168라길  서울특별시 강동구 천호대로168라길 18
# 15264              82000220  서울특별시  강동구  천호대로168라길   서울특별시 강동구 천호대로168라길 4
# 15265              82000221  서울특별시  강동구  천호대로168나길  서울특별시 강동구 천호대로168나길 44
# 15266              82000222  서울특별시  강동구  천호대로168나길  서울특별시 강동구 천호대로168나길 56
# 15267              82000223  서울특별시  강동구  천호대로168다길  서울특별시 강동구 천호대로168다길 54
#
# ...

# %%
서울과속방지턱.to_csv("output/서울과속방지턱.csv")

# %% [markdown]
# # 3. 서울 CCTV 위치정보

# %%
df = pd.read_csv("data/교통 데이터/서울특별시 불법주정차_전용차로 위반 단속 CCTV 위치정보.csv", encoding = 'ansi')
df
# Out:
#             고정형CCTV지번주소         위도          경도  자치구                 단속지점명  \
# 0     서울 양천구 목4동 762-10  37.535891  126.870566  양천구          목4동 영도초등학교 앞
# 1      서울 양천구 목4동 797-8  37.532740  126.867191  양천구             목4동 태학관 앞
# 2     서울 양천구 신월2동 452-2  37.526782  126.843910  양천구        신월2동 영림프라임샤시 앞
# 3     서울 양천구 신월7동 928-1  37.522349  126.833529  양천구           신월7동 우성상가 앞
# 4        서울 양천구 목1동 917  37.528982  126.874597  양천구        목1동 파라곤(SBS) 앞
# ...                 ...        ...         ...  ...                   ...
# 3316   서울 용산구 한강로2가 422  37.529105  126.966972  용산구                 용산역 앞
# 3317     서울 용산구 산천동 193  37.535002  126.950593  용산구           일민유치원 정문 위쪽
# 3318  서울 강북구 미아동 754-63  37.623281  127.021311  강북구           주정차(송천)-193
# 3319  서울 강남구 삼성동 141-19  37.505168  127.048947  강남구  [삼성2-113] 선릉역8번출구 주변
# 3320  서울 서초구 서초동 1348-9  37.486268  127.025877  서초구                   주택옆
#
#          현장구분
# 0     불법주정차구역
# 1     불법주정차구역
# 2     불법주정차구역
# 3     불법주정차구역
# ...

# %%
서울cctv = df

# %%
서울cctv.to_csv("output/서울cctv.csv")

# %% [markdown]
# # 4. 무인 교통 단속 카메라

# %%
df = pd.read_csv("data/교통 데이터/전국무인교통단속카메라표준데이터.csv", encoding = 'ansi')
df
# Out:
#       무인교통단속카메라관리번호   시도명 시군구명  도로종류 도로노선번호  도로노선명  도로노선방향  \
# 0             G0672  전라북도  완산구  일반국도    21번    호남로     NaN
# 1             G0673  전라북도  완산구    시도   해당없음  장승배기로     NaN
# 2             G0674  전라북도  완산구    시도   해당없음  장승배기로     NaN
# 3             G0675  전라북도  완산구    시도   해당없음   쑥고개로     NaN
# 4             G0676  전라북도  완산구    시도   해당없음    선비로     NaN
# ...             ...   ...  ...   ...    ...    ...     ...
# 13721         F4234  경상남도  진주시   지방도  1009번   월아산로     2.0
# 13722         F4237  경상남도  김해시  일반국도    14번   동서대로     2.0
# 13723         F4238  경상남도  양산시    시도    NaN  여락송정로     2.0
# 13724         F4241  경상남도  거제시  일반국도    14번   거제대로     2.0
# 13725         F4242  경상남도  밀양시   지방도  1008번    온천로     1.0
#
#                      소재지도로명주소                    소재지지번주소         위도  ...  \
# 0                         NaN    전라북도 전주시 완산구 용복동 산 35-6  35.774684  ...
# 1                         NaN      전라북도 전주시 완산구 서서학동 169  35.804901  ...
# ...

# %%
서울무인단속 = df[df["시도명"] == "서울특별시"]

# %%
서울무인단속
# Out:
#       무인교통단속카메라관리번호    시도명  시군구명  도로종류 도로노선번호     도로노선명  도로노선방향  \
# 106             035  서울특별시   광진구  특별시도    405       능동로     3.0
# 107             024  서울특별시   광진구  특별시도   3107      아차산로     3.0
# 108             006  서울특별시   광진구  특별시도   3109       자양로     3.0
# 109             004  서울특별시   광진구  특별시도   3001      광나루로     3.0
# 110             036  서울특별시   광진구  특별시도   4805       면목로     3.0
# ...             ...    ...   ...   ...    ...       ...     ...
# 13337      전농1_0004  서울특별시  동대문구    기타      0    서울시립대로     3.0
# 13338      전농1_0017  서울특별시  동대문구    기타      0  서울시립대로5길     3.0
# 13339      전농2_0010  서울특별시  동대문구    기타      0    전농로20길     3.0
# 13340       회기_0014  서울특별시  동대문구    기타      0       회기로     3.0
# 13341      휘경2_0032  서울특별시  동대문구    기타      0   장안벚꽃로5길     3.0
#
#                      소재지도로명주소                소재지지번주소         위도  ...  제한속도  \
# 106         서울특별시 광진구 능동로 109     서울특별시 광진구 화양동 5-84  37.540748  ...     0
# ...

# %%
서울무인단속.to_csv("output/서울무인단속.csv")
