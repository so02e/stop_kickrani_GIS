# %%
import pandas as pd
import numpy as np
import seaborn as sns

from matplotlib import font_manager, rc
font_path = "data/THEdog.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

import matplotlib.pyplot as plt


# %matplotlib inline

# %%
import pandas as pd

강원PM = pd.read_excel("data/교통사고 데이터/2017-2019년 강원도 PM 교통사고정보.xlsx")
강원PM
# Out:
#                 사고번호               사고일시   요일            시군구    사고내용  사망자수  \
# 0   2017070700100195    2017년 7월 7일 10시  금요일     강원도 양구군 남면    중상사고     0
# 1   2017092100100543   2017년 9월 21일 18시  목요일    강원도 춘천시 후평동    경상사고     0
# 2   2017100300100290   2017년 10월 3일 17시  화요일    강원도 양양군 강현면    경상사고     0
# 3   2017110200100283   2017년 11월 2일 14시  목요일     강원도 춘천시 동면    경상사고     0
# 4   2017111300100042  2017년 11월 13일 02시  월요일    강원도 춘천시 우두동  부상신고사고     0
# 5   2019080900100080    2019년 8월 9일 04시  금요일    강원도 춘천시 효자동    중상사고     0
# 6   2019081000100632   2019년 8월 10일 21시  토요일    강원도 원주시 우산동    경상사고     0
# 7   2019082500100361   2019년 8월 25일 17시  일요일    강원도 동해시 이도동    경상사고     0
# 8   2019083100100330   2019년 8월 31일 12시  토요일    강원도 춘천시 효자동    중상사고     0
# 9   2019092600100224   2019년 9월 26일 11시  목요일  강원도 춘천시 중앙로3가    경상사고     0
# 10  2019102500100098  2019년 10월 25일 06시  금요일    강원도 원주시 행구동    중상사고     0
#
#     중상자수  경상자수  부상신고자수              사고유형  ... 기상상태         도로형태     가해운전자 차종  \
# ...

# %%
경기PM = pd.read_excel("data/교통사고 데이터/2017-2019년 경기도 PM 교통사고정보.xlsx")
경기PM
# Out:
#                  사고번호               사고일시   요일               시군구    사고내용  사망자수  \
# 0    2017022500100119   2017년 2월 25일 06시  토요일   경기도 용인시 기흥구 보정동    중상사고     0
# 1    2017030100100243    2017년 3월 1일 15시  수요일    경기도 수원시 영통구 하동  부상신고사고     0
# 2    2017051100100465   2017년 5월 11일 19시  목요일      경기도 광명시 노온사동  부상신고사고     0
# 3    2017051800100131   2017년 5월 18일 08시  목요일   경기도 성남시 중원구 성남동    경상사고     0
# 4    2017053100100425   2017년 5월 31일 18시  수요일   경기도 안산시 단원구 고잔동    중상사고     0
# ..                ...                ...  ...               ...     ...   ...
# 203  2019121800100053  2019년 12월 18일 02시  수요일   경기도 수원시 팔달구 인계동    경상사고     0
# 204  2019121800100470  2019년 12월 18일 18시  수요일      경기도 의정부시 민락동    경상사고     0
# 205  2019121900100111  2019년 12월 19일 07시  목요일   경기도 안산시 단원구 고잔동    경상사고     0
# 206  2019122700100248  2019년 12월 27일 12시  금요일      경기도 이천시 장호원읍    중상사고     0
# 207  2019122800100068  2019년 12월 28일 01시  토요일  경기도 고양시 일산동구 성석동    중상사고     0
#
# ...

# %%
경남PM = pd.read_excel("data/교통사고 데이터/2017-2019년 경상남도 PM 교통사고정보.xlsx")
경북PM = pd.read_excel("data/교통사고 데이터/2017-2019년 경상북도 PM 교통사고정보.xlsx")
광주PM = pd.read_excel("data/교통사고 데이터/2017-2019년 광주광역시 PM 교통사고정보.xlsx")
대구PM = pd.read_excel("data/교통사고 데이터/2017-2019년 대구광역시 PM 교통사고정보.xlsx")
대전PM = pd.read_excel("data/교통사고 데이터/2017-2019년 대전광역시 PM 교통사고정보.xlsx")
부산PM = pd.read_excel("data/교통사고 데이터/2017-2019년 부산광역시 PM 교통사고정보.xlsx")
서울PM = pd.read_excel("data/교통사고 데이터/2017-2019년 서울시 PM 교통사고정보.xlsx")
세종PM = pd.read_excel("data/교통사고 데이터/2017-2019년 세종특별시 PM 교통사고정보.xlsx")
울산PM = pd.read_excel("data/교통사고 데이터/2017-2019년 울산광역시 PM 교통사고정보.xlsx")
인천PM = pd.read_excel("data/교통사고 데이터/2017-2019년 인천광역시 PM 교통사고정보.xlsx")
전남PM = pd.read_excel("data/교통사고 데이터/2017-2019년 전라남도 PM 교통사고정보.xlsx")
전북PM = pd.read_excel("data/교통사고 데이터/2017-2019년 전라북도 PM 교통사고정보.xlsx")
제주PM = pd.read_excel("data/교통사고 데이터/2017-2019년 제주도 PM 교통사고정보.xlsx")
충남PM = pd.read_excel("data/교통사고 데이터/2017-2019년 충청남도 PM 교통사고정보.xlsx")
충북PM = pd.read_excel("data/교통사고 데이터/2017-2019년 충청북도 PM 교통사고정보.xlsx")

# %%
PM = pd.concat([강원PM,경기PM,경남PM,경북PM,광주PM,대구PM,대전PM,부산PM,서울PM,세종PM,울산PM,인천PM,전남PM,전북PM,제주PM,충남PM,충북PM])
PM
# Out:
#                 사고번호               사고일시   요일               시군구    사고내용  사망자수  \
# 0   2017070700100195    2017년 7월 7일 10시  금요일        강원도 양구군 남면    중상사고     0
# 1   2017092100100543   2017년 9월 21일 18시  목요일       강원도 춘천시 후평동    경상사고     0
# 2   2017100300100290   2017년 10월 3일 17시  화요일       강원도 양양군 강현면    경상사고     0
# 3   2017110200100283   2017년 11월 2일 14시  목요일        강원도 춘천시 동면    경상사고     0
# 4   2017111300100042  2017년 11월 13일 02시  월요일       강원도 춘천시 우두동  부상신고사고     0
# ..               ...                ...  ...               ...     ...   ...
# 38  2019102800100095  2019년 10월 28일 07시  월요일  충청북도 청주시 상당구 용암동  부상신고사고     0
# 39  2019110100100225   2019년 11월 1일 09시  금요일  충청북도 청주시 서원구 사직동    경상사고     0
# 40  2019112800100586  2019년 11월 28일 19시  목요일  충청북도 청주시 상당구 용암동    경상사고     0
# 41  2019121700100580  2019년 12월 17일 21시  화요일  충청북도 청주시 흥덕구 비하동    경상사고     0
# 42  2019122200100324  2019년 12월 22일 16시  일요일  충청북도 청주시 흥덕구 향정동  부상신고사고     0
#
# ...

# %%
PM.to_csv("output/PM_accident.csv")

# %%
PM = pd.read_csv("output/PM_accident.csv")
PM
# Out:
#      Unnamed: 0              사고번호               사고일시   요일               시군구  \
# 0             0  2017070700100195    2017년 7월 7일 10시  금요일        강원도 양구군 남면
# 1             1  2017092100100543   2017년 9월 21일 18시  목요일       강원도 춘천시 후평동
# 2             2  2017100300100290   2017년 10월 3일 17시  화요일       강원도 양양군 강현면
# 3             3  2017110200100283   2017년 11월 2일 14시  목요일        강원도 춘천시 동면
# 4             4  2017111300100042  2017년 11월 13일 02시  월요일       강원도 춘천시 우두동
# ..          ...               ...                ...  ...               ...
# 784          38  2019102800100095  2019년 10월 28일 07시  월요일  충청북도 청주시 상당구 용암동
# 785          39  2019110100100225   2019년 11월 1일 09시  금요일  충청북도 청주시 서원구 사직동
# 786          40  2019112800100586  2019년 11월 28일 19시  목요일  충청북도 청주시 상당구 용암동
# 787          41  2019121700100580  2019년 12월 17일 21시  화요일  충청북도 청주시 흥덕구 비하동
# 788          42  2019122200100324  2019년 12월 22일 16시  일요일  충청북도 청주시 흥덕구 향정동
#
# ...

# %%
PM
# Out:
#      Unnamed: 0              사고번호               사고일시   요일               시군구  \
# 0             0  2017070700100195    2017년 7월 7일 10시  금요일        강원도 양구군 남면
# 1             1  2017092100100543   2017년 9월 21일 18시  목요일       강원도 춘천시 후평동
# 2             2  2017100300100290   2017년 10월 3일 17시  화요일       강원도 양양군 강현면
# 3             3  2017110200100283   2017년 11월 2일 14시  목요일        강원도 춘천시 동면
# 4             4  2017111300100042  2017년 11월 13일 02시  월요일       강원도 춘천시 우두동
# ..          ...               ...                ...  ...               ...
# 784          38  2019102800100095  2019년 10월 28일 07시  월요일  충청북도 청주시 상당구 용암동
# 785          39  2019110100100225   2019년 11월 1일 09시  금요일  충청북도 청주시 서원구 사직동
# 786          40  2019112800100586  2019년 11월 28일 19시  목요일  충청북도 청주시 상당구 용암동
# 787          41  2019121700100580  2019년 12월 17일 21시  화요일  충청북도 청주시 흥덕구 비하동
# 788          42  2019122200100324  2019년 12월 22일 16시  일요일  충청북도 청주시 흥덕구 향정동
#
# ...

# %%
a = PM[PM["법규위반"] == "안전운전불이행"]
a
# Out:
#      Unnamed: 0              사고번호               사고일시   요일               시군구  \
# 0             0  2017070700100195    2017년 7월 7일 10시  금요일        강원도 양구군 남면
# 3             3  2017110200100283   2017년 11월 2일 14시  목요일        강원도 춘천시 동면
# 4             4  2017111300100042  2017년 11월 13일 02시  월요일       강원도 춘천시 우두동
# 5             5  2019080900100080    2019년 8월 9일 04시  금요일       강원도 춘천시 효자동
# 7             7  2019082500100361   2019년 8월 25일 17시  일요일       강원도 동해시 이도동
# ..          ...               ...                ...  ...               ...
# 784          38  2019102800100095  2019년 10월 28일 07시  월요일  충청북도 청주시 상당구 용암동
# 785          39  2019110100100225   2019년 11월 1일 09시  금요일  충청북도 청주시 서원구 사직동
# 786          40  2019112800100586  2019년 11월 28일 19시  목요일  충청북도 청주시 상당구 용암동
# 787          41  2019121700100580  2019년 12월 17일 21시  화요일  충청북도 청주시 흥덕구 비하동
# 788          42  2019122200100324  2019년 12월 22일 16시  일요일  충청북도 청주시 흥덕구 향정동
#
# ...

# %%
PM.describe()
# Out:
#                사고번호        사망자수        중상자수        경상자수      부상신고자수
# count  7.890000e+02  789.000000  789.000000  789.000000  789.000000
# mean   2.018498e+15    0.020279    0.318124    0.555133    0.185044
# std    7.353959e+11    0.141042    0.492521    0.570924    0.388580
# min    2.017022e+15    0.000000    0.000000    0.000000    0.000000
# 25%    2.018071e+15    0.000000    0.000000    0.000000    0.000000
# 50%    2.019043e+15    0.000000    0.000000    1.000000    0.000000
# 75%    2.019083e+15    0.000000    1.000000    1.000000    0.000000
# max    2.019123e+15    1.000000    2.000000    3.000000    1.000000

# %% [markdown]
# ### 연도에 따른 PM 사고

# %%
PM.columns
# Out:
# Index(['사고번호', '사고일시', '요일', '시군구', '사고내용', '사망자수', '중상자수', '경상자수', '부상신고자수',
#        '사고유형', '법규위반', '노면상태', '기상상태', '도로형태', '가해운전자 차종', '가해운전자 성별',
#        '가해운전자 연령', '가해운전자 상해정도', '피해운전자 차종', '피해운전자 성별', '피해운전자 연령',
#        '피해운전자 상해정도'],
#       dtype='object')

# %%
new_PM = PM[['사고일시', '요일', '시군구', '사고내용', '사망자수', '중상자수', '경상자수', '부상신고자수',
       '사고유형', '법규위반', '노면상태', '도로형태', '가해운전자 차종', '가해운전자 성별',
       '가해운전자 연령', '가해운전자 상해정도', '피해운전자 차종', '피해운전자 성별', '피해운전자 연령',
       '피해운전자 상해정도']]

# %%
new_PM
# Out:
#                  사고일시   요일               시군구    사고내용  사망자수  중상자수  경상자수  \
# 0     2017년 7월 7일 10시  금요일        강원도 양구군 남면    중상사고     0     1     0
# 1    2017년 9월 21일 18시  목요일       강원도 춘천시 후평동    경상사고     0     0     1
# 2    2017년 10월 3일 17시  화요일       강원도 양양군 강현면    경상사고     0     0     3
# 3    2017년 11월 2일 14시  목요일        강원도 춘천시 동면    경상사고     0     0     1
# 4   2017년 11월 13일 02시  월요일       강원도 춘천시 우두동  부상신고사고     0     0     0
# ..                ...  ...               ...     ...   ...   ...   ...
# 38  2019년 10월 28일 07시  월요일  충청북도 청주시 상당구 용암동  부상신고사고     0     0     0
# 39   2019년 11월 1일 09시  금요일  충청북도 청주시 서원구 사직동    경상사고     0     0     1
# 40  2019년 11월 28일 19시  목요일  충청북도 청주시 상당구 용암동    경상사고     0     0     1
# 41  2019년 12월 17일 21시  화요일  충청북도 청주시 흥덕구 비하동    경상사고     0     0     1
# 42  2019년 12월 22일 16시  일요일  충청북도 청주시 흥덕구 향정동  부상신고사고     0     0     0
#
#     부상신고자수              사고유형       법규위반     노면상태         도로형태     가해운전자 차종  \
# ...

# %%
사고일시 = new_PM['사고일시'].str.split(" ")

print(type(사고일시))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# 각각의 데이터는 리스트입니다.
print(type(사고일시[0]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
사고일시.head()
# Out:
# 0      [2017년, 7월, 7일, 10시]
# 1     [2017년, 9월, 21일, 18시]
# 2     [2017년, 10월, 3일, 17시]
# 3     [2017년, 11월, 2일, 14시]
# 4    [2017년, 11월, 13일, 02시]
# Name: 사고일시, dtype: object

# %%
사고일시
# Out:
# 0       [2017년, 7월, 7일, 10시]
# 1      [2017년, 9월, 21일, 18시]
# 2      [2017년, 10월, 3일, 17시]
# 3      [2017년, 11월, 2일, 14시]
# 4     [2017년, 11월, 13일, 02시]
#                ...
# 38    [2019년, 10월, 28일, 07시]
# 39     [2019년, 11월, 1일, 09시]
# 40    [2019년, 11월, 28일, 19시]
# 41    [2019년, 12월, 17일, 21시]
# 42    [2019년, 12월, 22일, 16시]
# Name: 사고일시, Length: 789, dtype: object

# %%
# .str 접근자(accessor)를 사용하면 
# 리스트의 인덱싱과 같은 방식으로 데이터를 추출할 수 있습니다.
# 리스트에서 첫번째 요소를 가져옵니다.
연도 = 사고일시.str[0]

# 결과를 출력합니다
print(연도.head())
# Out:
# 0    2017년
# 1    2017년
# 2    2017년
# 3    2017년
# 4    2017년
# Name: 사고일시, dtype: object

# %%
# .str 접근자(accessor)를 사용하면 
# 리스트의 인덱싱과 같은 방식으로 데이터를 추출할 수 있습니다.
# 리스트에서 마지막 요소를 가져옵니다.
시간 = 사고일시.str[-1]

# 결과를 출력합니다
print(시간.head())
# Out:
# 0    10시
# 1    18시
# 2    17시
# 3    14시
# 4    02시
# Name: 사고일시, dtype: object

# %%
# 인덱싱 결과를 새로운 변수에 할당합니다.
new_PM['사고연도'] = 연도

# 인덱싱 결과를 새로운 변수에 할당합니다.
new_PM['사고시간'] = 시간
# Out:
# <ipython-input-15-0795d489c329>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_PM['사고연도'] = 연도

# %%
new_PM
# Out:
#                  사고일시   요일               시군구    사고내용  사망자수  중상자수  경상자수  \
# 0     2017년 7월 7일 10시  금요일        강원도 양구군 남면    중상사고     0     1     0
# 1    2017년 9월 21일 18시  목요일       강원도 춘천시 후평동    경상사고     0     0     1
# 2    2017년 10월 3일 17시  화요일       강원도 양양군 강현면    경상사고     0     0     3
# 3    2017년 11월 2일 14시  목요일        강원도 춘천시 동면    경상사고     0     0     1
# 4   2017년 11월 13일 02시  월요일       강원도 춘천시 우두동  부상신고사고     0     0     0
# ..                ...  ...               ...     ...   ...   ...   ...
# 38  2019년 10월 28일 07시  월요일  충청북도 청주시 상당구 용암동  부상신고사고     0     0     0
# 39   2019년 11월 1일 09시  금요일  충청북도 청주시 서원구 사직동    경상사고     0     0     1
# 40  2019년 11월 28일 19시  목요일  충청북도 청주시 상당구 용암동    경상사고     0     0     1
# 41  2019년 12월 17일 21시  화요일  충청북도 청주시 흥덕구 비하동    경상사고     0     0     1
# 42  2019년 12월 22일 16시  일요일  충청북도 청주시 흥덕구 향정동  부상신고사고     0     0     0
#
#     부상신고자수              사고유형       법규위반  ... 가해운전자 성별 가해운전자 연령 가해운전자 상해정도  \
# ...

# %%
시군구 = new_PM['시군구'].str.split(" ")

시군구
# Out:
# 0            [강원도, 양구군, 남면]
# 1           [강원도, 춘천시, 후평동]
# 2           [강원도, 양양군, 강현면]
# 3            [강원도, 춘천시, 동면]
# 4           [강원도, 춘천시, 우두동]
#               ...
# 38    [충청북도, 청주시, 상당구, 용암동]
# 39    [충청북도, 청주시, 서원구, 사직동]
# 40    [충청북도, 청주시, 상당구, 용암동]
# 41    [충청북도, 청주시, 흥덕구, 비하동]
# 42    [충청북도, 청주시, 흥덕구, 향정동]
# Name: 시군구, Length: 789, dtype: object

# %%
# .str 접근자(accessor)를 사용하면 
# 리스트의 인덱싱과 같은 방식으로 데이터를 추출할 수 있습니다.
# 리스트에서 첫번째 요소를 가져옵니다.
지역 = 시군구.str[0]

# 결과를 출력합니다
print(지역.head())
# Out:
# 0    강원도
# 1    강원도
# 2    강원도
# 3    강원도
# 4    강원도
# Name: 시군구, dtype: object

# %%
new_PM['지역'] = 지역

# %%
new_PM
# Out:
#                  사고일시   요일               시군구    사고내용  사망자수  중상자수  경상자수  \
# 0     2017년 7월 7일 10시  금요일        강원도 양구군 남면    중상사고     0     1     0
# 1    2017년 9월 21일 18시  목요일       강원도 춘천시 후평동    경상사고     0     0     1
# 2    2017년 10월 3일 17시  화요일       강원도 양양군 강현면    경상사고     0     0     3
# 3    2017년 11월 2일 14시  목요일        강원도 춘천시 동면    경상사고     0     0     1
# 4   2017년 11월 13일 02시  월요일       강원도 춘천시 우두동  부상신고사고     0     0     0
# ..                ...  ...               ...     ...   ...   ...   ...
# 38  2019년 10월 28일 07시  월요일  충청북도 청주시 상당구 용암동  부상신고사고     0     0     0
# 39   2019년 11월 1일 09시  금요일  충청북도 청주시 서원구 사직동    경상사고     0     0     1
# 40  2019년 11월 28일 19시  목요일  충청북도 청주시 상당구 용암동    경상사고     0     0     1
# 41  2019년 12월 17일 21시  화요일  충청북도 청주시 흥덕구 비하동    경상사고     0     0     1
# 42  2019년 12월 22일 16시  일요일  충청북도 청주시 흥덕구 향정동  부상신고사고     0     0     0
#
#     부상신고자수              사고유형       법규위반  ... 가해운전자 성별 가해운전자 연령 가해운전자 상해정도  \
# ...

# %%
new_PM["법규위반"].value_counts()
# Out:
# 안전운전불이행      490
# 기타            74
# 신호위반          74
# 중앙선침범         51
# 교차로운행방법위반     33
# 불법유턴          21
# 안전거리미확보       16
# 직진우회전진행방해     16
# 보행자보호의무위반     11
# 차로위반           3
# Name: 법규위반, dtype: int64

# %%
plt.figure(figsize = (15,10))
sns.countplot(data=new_PM, x="법규위반",palette = "Set3")
plt.title("개인형 이동수단(PM) 교통사고 법규위반", fontsize = 25)
plt.xlabel('법규위반', fontsize = 20)
plt.ylabel('건', fontsize = 20)
plt.xticks(rotation = -45, fontsize = 15)

plt.savefig("output/개인형 이동수단(PM) 교통사고 법규위반.png")

# %%
plt.figure(figsize = (20,15))
sns.countplot(data=new_PM, x="사고유형",palette = "Set3")
plt.title("개인형 이동수단(PM) 교통사고 사고유형", fontsize = 25)
plt.xlabel('사고유형', fontsize = 20)
plt.ylabel('건', fontsize = 20)
plt.xticks(rotation = -45, fontsize = 15)

plt.savefig("output/개인형 이동수단(PM) 교통사고 사고유형.png")

# %%
"""
ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()
"""

## 연령대별 구분

age = new_PM[["가해운전자 연령","가해운전자 성별"]]

# %%
age
# Out:
#    가해운전자 연령 가해운전자 성별
# 0       73세        여
# 1       45세        남
# 2       67세        남
# 3       33세        남
# 4       39세        남
# ..      ...      ...
# 38      58세        여
# 39      22세        남
# 40      60세        남
# 41      36세        남
# 42      40세        남
#
# [789 rows x 2 columns]

# %%
age.dtypes
# Out:
# 가해운전자 연령    object
# 가해운전자 성별    object
# dtype: object

# %%
age
# Out:
#    가해운전자 연령 가해운전자 성별
# 0       73세        여
# 1       45세        남
# 2       67세        남
# 3       33세        남
# 4       39세        남
# ..      ...      ...
# 38      58세        여
# 39      22세        남
# 40      60세        남
# 41      36세        남
# 42      40세        남
#
# [789 rows x 2 columns]

# %%
연령 = age["가해운전자 연령"].str.split("세")


연령 = 연령.str[0]

# 결과를 출력합니다
print(연령.head())
# Out:
# 0    73
# 1    45
# 2    67
# 3    33
# 4    39
# Name: 가해운전자 연령, dtype: object

# %%
연령
# Out:
# 0     73
# 1     45
# 2     67
# 3     33
# 4     39
#       ..
# 38    58
# 39    22
# 40    60
# 41    36
# 42    40
# Name: 가해운전자 연령, Length: 789, dtype: object

# %%
age['연령'] = 연령
# Out:
# <ipython-input-109-6da5906c3d7d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age['연령'] = 연령

# %%
age
# Out:
#    가해운전자 연령 가해운전자 성별  연령
# 0       73세        여  73
# 1       45세        남  45
# 2       67세        남  67
# 3       33세        남  33
# 4       39세        남  39
# ..      ...      ...  ..
# 38      58세        여  58
# 39      22세        남  22
# 40      60세        남  60
# 41      36세        남  36
# 42      40세        남  40
#
# [789 rows x 3 columns]

# %%
age = age.sort_values(by='연령', ascending=True)
age
# Out:
#     가해운전자 연령 가해운전자 성별   연령
# 131      10세        남   10
# 3        10세        남   10
# 27       10세        남   10
# 6        10세        남   10
# 6        10세        남   10
# ..       ...      ...  ...
# 10       미분류     기타불명  미분류
# 13       미분류     기타불명  미분류
# 105      미분류     기타불명  미분류
# 0        미분류     기타불명  미분류
# 149      미분류     기타불명  미분류
#
# [789 rows x 3 columns]

# %%
age['연령'] = pd.to_numeric(age['연령'])
age
# Out:
# <ipython-input-120-0d4260bbdbca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   age['연령'] = pd.to_numeric(age['연령'])
#     가해운전자 연령 가해운전자 성별  연령
# 131      10세        남  10
# 3        10세        남  10
# 27       10세        남  10
# 6        10세        남  10
# 6        10세        남  10
# ..       ...      ...  ..
# 10        9세        남   9
# 1     90세 이상        남  90
# 31    90세 이상        남  90
# 6     90세 이상        남  90
# 7     90세 이상        남  90
#
# [782 rows x 3 columns]

# %%
age.dtypes
# Out:
# 가해운전자 연령    object
# 가해운전자 성별    object
# 연령           int64
# dtype: object

# %%
age = age.sort_values(by='연령', ascending=True)
age
# Out:
#     가해운전자 연령 가해운전자 성별  연령
# 0         6세        남   6
# 9         6세        여   6
# 25        7세        남   7
# 20        8세        남   8
# 10        9세        남   9
# ..       ...      ...  ..
# 199      89세        남  89
# 6     90세 이상        남  90
# 1     90세 이상        남  90
# 31    90세 이상        남  90
# 7     90세 이상        남  90
#
# [782 rows x 3 columns]

# %%
age = age[~age["가해운전자 연령"].str.contains("미분류")]

# %%
plt.figure(figsize = (20,15))

sns.countplot(data=age, x="연령",palette = "Set3")

plt.title("개인형 이동수단(PM) 교통사고 가해자 연령", fontsize = 25)
plt.xlabel('연령', fontsize = 20)
plt.ylabel('건', fontsize = 20)
plt.xticks(rotation = -45, fontsize = 10)

plt.savefig("output/개인형 이동수단(PM) 교통사고 가해자 연령.png")

# %%
new_PM_year = new_PM[["사고연도","사고유형","법규위반"]]

# %%
new_PM_year.groupby(by=['사고연도'], as_index=False).count()
# Out:
#     사고연도  사고유형  법규위반
# 0  2017년   117   117
# 1  2018년   225   225
# 2  2019년   447   447

# %%
new_PM_year.groupby(by=["사고유형"], as_index=False).count()
# Out:
#                  사고유형  사고연도  법규위반
# 0           차대사람 - 기타   102   102
# 1   차대사람 - 길가장자리구역통행중     7     7
# 2        차대사람 - 보도통행중    51    51
# 3        차대사람 - 차도통행중    17    17
# 4          차대사람 - 횡단중    47    47
# 5            차대차 - 기타   194   194
# 6          차대차 - 정면충돌    32    32
# 7            차대차 - 추돌    17    17
# 8          차대차 - 측면충돌   218   218
# 9        차량단독 - 공작물충돌    11    11
# 10          차량단독 - 기타    56    56
# 11  차량단독 - 도로외이탈 - 기타     1     1
# 12  차량단독 - 도로외이탈 - 추락     1     1
# 13        차량단독 - 전도전복    12    12
# 14   차량단독 - 전도전복 - 전도    21    21
# 15   차량단독 - 전도전복 - 전복     2     2

# %%
new_PM_year.groupby(by=['법규위반'], as_index=False).count()
# Out:
#         법규위반  사고연도  사고유형
# 0  교차로운행방법위반    33    33
# 1         기타    74    74
# 2  보행자보호의무위반    11    11
# 3       불법유턴    21    21
# 4       신호위반    74    74
# 5    안전거리미확보    16    16
# 6    안전운전불이행   490   490
# 7      중앙선침범    51    51
# 8  직진우회전진행방해    16    16
# 9       차로위반     3     3

# %%
new_PM_year
# Out:
#      사고연도              사고유형       법규위반
# 0   2017년  차량단독 - 전도전복 - 전복    안전운전불이행
# 1   2017년        차대차 - 측면충돌       불법유턴
# 2   2017년        차대차 - 측면충돌  교차로운행방법위반
# 3   2017년         차량단독 - 기타    안전운전불이행
# 4   2017년       차량단독 - 전도전복    안전운전불이행
# ..    ...               ...        ...
# 38  2019년        차대차 - 측면충돌    안전운전불이행
# 39  2019년          차대차 - 기타    안전운전불이행
# 40  2019년        차대차 - 측면충돌    안전운전불이행
# 41  2019년          차대차 - 기타    안전운전불이행
# 42  2019년          차대차 - 기타    안전운전불이행
#
# [789 rows x 3 columns]

# %%
plt.figure(figsize = (15,10))
sns.countplot(data=new_PM_year, x="사고유형",palette = "Set3")
#plt.title("개인형 이동수단(PM) 교통사고 법규위반", fontsize = 25)
#plt.xlabel('법규위반', fontsize = 20)
#plt.ylabel('건', fontsize = 20)
plt.xticks(rotation = -45, fontsize = 15)
plt.show()
#plt.savefig("output/개인형 이동수단(PM) 교통사고 법규위반.png")
