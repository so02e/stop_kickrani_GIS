# %%
import pandas as pd
import numpy as np
import seaborn as sns

df1 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_01_P_병원.xlsx")
df1
# Out:
# C:\Users\user\anaconda3\envs\pydatavenv\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       번호 개방서비스명     개방서비스ID  개방자치단체코드                       관리번호     인허가일자  \
# 0      1     병원  01_01_01_P   3000000  PHMA219793000034021200001  19790324
# 1      2     병원  01_01_01_P   3000000  PHMA220043000034021200001  20040901
# 2      3     병원  01_01_01_P   3000000  PHMA219873000034021200001  19870424
# 3      4     병원  01_01_01_P   3000000  PHMA219813000034021200001  19810709
# 4      5     병원  01_01_01_P   3000000  PHMA220183000034021200001  20180416
# ..   ...    ...         ...       ...                        ...       ...
# 819  820     병원  01_01_01_P   3240000  PHMA220093240033021200002  20090820
# 820  821     병원  01_01_01_P   3240000  PHMA219833240033021200003  19830803
# ...

# %%
df2 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_01_P_병원.xlsx")
df3 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_02_P_의원.xlsx")
df4 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_03_P_부속의료기관.xlsx")
df5 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_04_P_산후조리업.xlsx")
df6 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_05_P_안전상비의약품 판매업소.xlsx")
df7 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_06_P_약국.xlsx")
df8 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_07_P_응급환자이송업.xlsx")
df9 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_08_P_의료법인.xlsx")
df10 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_01_10_P_의료유사업.xlsx")
df11 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_02_01_P_안경업.xlsx")
df12 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_02_02_P_의료기기수리업.xlsx")
df13 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_02_03_P_의료기기판매(임대)업.xlsx")
df14 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_01_02_04_P_치과기공소.xlsx")
# Out:
# C:\Users\user\anaconda3\envs\pydatavenv\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df14
# Out:
#         번호 개방서비스명     개방서비스ID  개방자치단체코드                       관리번호     인허가일자  \
# 0        1  치과기공소  01_02_04_P   3000000  PHMB320023000034062300001  20020919
# 1        2  치과기공소  01_02_04_P   3000000  PHMB320153000034062300002  20150526
# 2        3  치과기공소  01_02_04_P   3000000  PHMB319763000034062300001  19760807
# 3        4  치과기공소  01_02_04_P   3000000  PHMB320063000034062300001  20061211
# 4        5  치과기공소  01_02_04_P   3000000  PHMB319783000034062300002  19770831
# ...    ...    ...         ...       ...                        ...       ...
# 2026  2027  치과기공소  01_02_04_P   3240000  PHMB320123240033062300005  20120629
# 2027  2028  치과기공소  01_02_04_P   3240000  PHMB320133240033062300001  20130522
# 2028  2029  치과기공소  01_02_04_P   3240000  PHMB320103240033062300001  20100316
# 2029  2030  치과기공소  01_02_04_P   3240000  PHMB320113240033062300004  20110616
# 2030  2031  치과기공소  01_02_04_P   3240000  PHMB320043240033062300006  20041018
#
# ...

# %%
df15 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_03_01_P_동물병원.xlsx")
df16 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_03_02_P_동물약국.xlsx")
df17 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_03_03_P_동물용의료용구판매업.xlsx")
df18 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_03_04_P_동물용의약품도매상.xlsx")
df19 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_03_05_P_동물장묘업.xlsx")
df20 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_03_06_P_동물판매업.xlsx")
df21 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_04_01_P_가축사육업.xlsx")
df22 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_04_02_P_가축인공수정소.xlsx")
df23 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_04_03_P_도축업.xlsx")
df24 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_04_04_P_부화업.xlsx")
df25 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_04_05_P_사료제조업.xlsx")
df26 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_02_04_06_P_종축업.xlsx")

# %%
df27 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_05_01_P_게임물배급업.xlsx")
df28 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_05_02_P_게임물제작업.xlsx")
df29 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_05_03_P_복합영상물제공업.xlsx")
df30 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_05_04_P_복합유통게임제공업.xlsx")
df31 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_05_05_P_인터넷컴퓨터게임시설제공업.xlsx")
df32 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_05_06_P_일반게임제공업.xlsx")
df33 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_05_07_P_청소년게임제공업.xlsx")
df34 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_06_01_P_공연장.xlsx")
df35 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_06_02_P_관광공연장업.xlsx")
df36 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_06_03_P_관광극장유흥업.xlsx")
df37 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_01_P_관광궤도업.xlsx")
df38 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_02_P_관광사업자.xlsx")
df39 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_03_P_관광유람선업.xlsx")
df40 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_04_P_국제회의시설업.xlsx")
df41 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_05_P_박물관, 미술관.xlsx")
df42 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_06_P_시내순환관광업.xlsx")
df43 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_08_P_유원시설업(기타).xlsx")
df44 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_09_P_일반유원시설업.xlsx")
df45 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_10_P_전문휴양업.xlsx")
df46 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_11_P_전통사찰.xlsx")
df47 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_12_P_종합유원시설업.xlsx")
df48 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_13_P_종합휴양업.xlsx")
df49 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_07_14_P_지방문화원.xlsx")
df50 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_08_01_P_국제회의기획업.xlsx")
df51 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_08_02_P_대중문화예술기획업.xlsx")
df52 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_08_03_P_문화예술법인.xlsx")
df53 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_09_01_P_노래연습장업.xlsx")
df54 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_10_01_P_비디오물감상실업.xlsx")
df55 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_10_02_P_비디오물배급업.xlsx")
df76 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_10_03_P_비디오물소극장업.xlsx")
df77 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_10_04_P_비디오물시청제공업.xlsx")
df78 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_10_05_P_비디오물제작업.xlsx")
df56 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_11_01_P_관광숙박업.xlsx")
df57 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_11_02_P_관광펜션업.xlsx")
df58 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_11_03_P_숙박업.xlsx")
df59 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_11_04_P_외국인관광도시민박업.xlsx")
df60 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_11_05_P_자동차야영장업.xlsx")
df61 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_11_06_P_한옥체험업.xlsx")
df62 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_11_07_P_일반야영장업.xlsx")
df63 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_12_01_P_국내여행업.xlsx")
df64 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_12_02_P_국외여행업.xlsx")
df65 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_12_03_P_일반여행업.xlsx")
df66 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_13_01_P_영화배급업.xlsx")
df67 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_13_02_P_영화상영관.xlsx")
df68 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_13_03_P_영화상영업.xlsx")
df69 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_13_04_P_영화수입업.xlsx")
df70 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_13_05_P_영화제작업.xlsx")
df71 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_14_01_P_온라인음악서비스제공업.xlsx")
df72 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_14_02_P_음반.음악영상물배급업.xlsx")
df73 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_14_03_P_음반.음악영상물제작업.xlsx")
df74 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_14_04_P_음반물배급업.xlsx")
df75 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_03_14_05_P_음반물제작업.xlsx")

# %%
df79 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_04_15_01_P_옥외광고업.xlsx")
df80 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_04_16_01_P_인쇄사.xlsx")
df81 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_04_17_01_P_출판사.xlsx")
df82 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_05_18_01_P_미용업.xlsx")
df83 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_05_19_01_P_이용업.xlsx")
df84 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_06_20_01_P_세탁업.xlsx")
df85 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_06_20_02_P_의료기관세탁물처리업.xlsx")

# %%
df86 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_21_01_P_위탁급식영업.xlsx")
df87 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_21_02_P_집단급식소.xlsx")
df88 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_01_P_집단급식소식품판매업.xlsx")
df89 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_02_P_건강기능식품유통전문판매업.xlsx")
df90 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_03_P_건강기능식품일반판매업.xlsx")
df91 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_04_P_축산판매업.xlsx")
df92 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_05_P_축산가공업.xlsx")
df93 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_06_P_식육포장처리업.xlsx")
df94 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_07_P_식품냉동냉장업.xlsx")
df95 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_08_P_식품소분업.xlsx")
df96 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_09_P_식품운반업.xlsx")
df97 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_10_P_식품자동판매기업.xlsx")
df98 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_11_P_식품제조가공업.xlsx")
df99 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_12_P_식품첨가물제조업.xlsx")
df100 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_13_P_식품판매업(기타).xlsx")
df101 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_14_P_옹기류제조업.xlsx")
df102 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_15_P_용기·포장지제조업.xlsx")
df117 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_16_P_용기냉동기특정설비.xlsx")
df103 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_17_P_유통전문판매업.xlsx")
df104 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_18_P_제과점영업.xlsx")
df105 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_19_P_즉석판매제조가공업.xlsx")
df106 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_20_P_집유업.xlsx")
df107 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_21_P_식용얼음판매업.xlsx")
df108 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_24_P_축산물보관업.xlsx")
df109 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_22_25_P_축산물운반업.xlsx")
df110 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_23_01_P_단란주점영업.xlsx")
df111 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_23_02_P_유흥주점영업.xlsx")
df112 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_24_01_P_관광식당.xlsx")
df113 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_24_02_P_관광유흥음식점업.xlsx")
df114 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_24_03_P_외국인전용유흥음식점업.xlsx")
df115 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_24_04_P_일반음식점.xlsx")
df116 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_07_24_05_P_휴게음식점.xlsx")

# %%
df118 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_08_25_01_P_대규모점포.xlsx")
df119 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_08_26_01_P_다단계판매업체.xlsx")
df120 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_08_26_02_P_방문판매업.xlsx")
df121 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_08_26_03_P_전화권유판매업.xlsx")
df122 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_08_26_04_P_통신판매업.xlsx")
df123 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_08_26_05_P_후원방문판매업체.xlsx")

# %%
df124 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_27_01_P_목재수입유통업.xlsx")
df125 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_27_02_P_원목생산업.xlsx")
df126 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_27_03_P_제재업.xlsx")
df127 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_01_P_계량기수리업.xlsx")
df128 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_02_P_계량기수입업.xlsx")
df129 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_03_P_계량기제조업.xlsx")
df130 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_04_P_계량기증명업.xlsx")
df131 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_05_P_고압가스업.xlsx")
df132 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_06_P_석연탄제조업.xlsx")
df133 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_07_P_석유및석유대체연료판매업체.xlsx")
df134 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_08_P_석유판매업.xlsx")
df135 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_09_P_액화석유가스용품제조업체.xlsx")
df136 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_10_P_일반도시가스업체.xlsx")
df137 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_11_P_전력기술감리업체.xlsx")
df138 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_12_P_전력기술설계업체.xlsx")
df139 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_28_13_P_특정고압가스업.xlsx")
df140 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_29_01_P_지하수시공업체.xlsx")
df141 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_29_02_P_지하수영향조사기관.xlsx")
df142 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_29_03_P_지하수정화업체.xlsx")
df143 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_01_P_가축분뇨 수집운반업.xlsx")
df144 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_02_P_가축분뇨배출시설관리업(사업장).xlsx")
df145 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_03_P_개인하수처리사설관리업(사업장).xlsx")
df146 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_04_P_건물위생관리업.xlsx")
df147 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_05_P_건설폐기물처리업.xlsx")
df148 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_06_P_급수공사대행업.xlsx")
df149 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_07_P_단독정화오수처리시설설계시공업.xlsx")
df150 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_08_P_대기오염물질배출시설설치사업장.xlsx")
df151 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_09_P_배출가스전문정비사업자(확인검사대행자).xlsx")
df152 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_10_P_분뇨수집운반업.xlsx")
df153 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_11_P_소독업.xlsx")
df154 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_12_P_수질오염원설치시설(기타).xlsx")
df155 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_13_P_쓰레기종량제봉투판매업.xlsx")
df156 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_14_P_저수조청소업.xlsx")
df157 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_15_P_환경관리대행기관.xlsx")
df158 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_16_P_환경전문공사업.xlsx")
df159 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_17_P_환경측정대행업.xlsx")
df160 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_09_30_18_P_환경컨설팅회사.xlsx")

# %%
df161 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_31_01_P_골프연습장업.xlsx")
df162 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_31_02_P_골프장.xlsx")
df163 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_31_03_P_등록체육시설업.xlsx")
df164 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_32_01_P_당구장업.xlsx")
df165 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_33_01_P_무도장업.xlsx")
df166 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_33_02_P_무도학원업.xlsx")
df167 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_34_01_P_빙상장업.xlsx")
df168 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_35_01_P_수영장업.xlsx")
df169 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_36_01_P_스키장.xlsx")
df170 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_37_01_P_종합체육시설업.xlsx")
df171 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_38_01_P_승마장업.xlsx")
df172 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_39_01_P_썰매장업.xlsx")
df173 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_40_01_P_요트장업.xlsx")
df174 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_41_01_P_체육도장업.xlsx")
df175 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_10_42_01_P_체력단련장업.xlsx")

# %%
df176 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_43_01_P_담배도매업.xlsx")
df177 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_43_02_P_담배소매업.xlsx")
df178 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_43_03_P_담배수입판매업체.xlsx")
df179 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_44_01_P_목욕장업.xlsx")
df180 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_45_01_P_물류주선업(국제).xlsx")
df181 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_45_02_P_물류창고업체.xlsx")
df182 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_46_01_P_민방위급수시설.xlsx")
df183 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_46_02_P_민방위대피시설.xlsx")
df184 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_47_01_P_상조업.xlsx")
df185 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_48_01_P_승강기유지관리업체.xlsx")
df186 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_48_02_P_승강기제조및수입업체.xlsx")
df187 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_49_01_P_요양보호사교육기관.xlsx")
df188 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_49_02_P_장례지도사 교육기관.xlsx")
df189 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_50_01_P_무료직업소개소.xlsx")
df190 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_50_02_P_유료직업소개소.xlsx")
df191 = pd.read_excel("data/서울시 시설 데이터/서울시 인허가 데이터/6110000_서울특별시_11_50_03_P_행정사업.xlsx")
